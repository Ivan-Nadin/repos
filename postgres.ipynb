# %%
import requests
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
from PIL import Image
from io import BytesIO

# %%
if __name__ == "__main__":
    name = "input.mkv"

    times = []
    times.append(["00:00:00", "00:00:10"])
    times.append(["00:06:00", "00:07:00"])

    # times = [["00:00:00", get_duration(name)]]

    if len(times) == 1:
        time = times[0]
        cmd = ["ffmpeg", "-i", name, "-ss", time[0], "-to", time[1], "-c:v", "copy", "-c:a", "copy", "output.mp4"]
        subprocess.check_output(cmd)
    else:
        open('concatenate.txt', 'w').close()
        for idx, time in enumerate(times):
            output_filename = f"output{idx}.mp4"
            cmd = ["ffmpeg", "-i", name, "-ss", time[0], "-to", time[1], "-c:v", "copy", "-c:a", "copy", output_filename]
            subprocess.check_output(cmd)

            with open("concatenate.txt", "a") as myfile:
                myfile.write(f"file {output_filename}\n")

        cmd = ["ffmpeg", "-f", "concat", "-i", "concatenate.txt", "-c", "copy", "output.mp4"]
        output = subprocess.check_output(cmd).decode("utf-8").strip()

# %%
times = []
time = times[0]
name = "input.mkv"
times.append(["00:00:00", "00:00:10"])
times.append(["00:06:00", "00:07:00"])
cmd = ["ffmpeg", "-i", name, "-ss", time[0], "-to", time[1], "-c:v", "copy", "-c:a", "copy", "output.mp4"]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-0e82f30e63b7> in <module>
#       1 times = []
# ----> 2 time = times[0]
#       3 name = "input.mkv"
#       4 times.append(["00:00:00", "00:00:10"])
#       5 times.append(["00:06:00", "00:07:00"])
#
# IndexError: list index out of range

# %%
from io import BytesIO

# %%
import io
s = io.BytesIO(r.content)
audio=AudioSegment.from_file(s)
audio = audio.set_frame_rate(16000)
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
result = bytes.fromhex(mobile_records[0][0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-c9197c873e36> in <module>
# ----> 1 result = bytes.fromhex(mobile_records[0][0])
#
# NameError: name 'mobile_records' is not defined

# %%
import requests

# %%
URL='https://api.telegram.org/bot1364390634:AAE88BzBzOJKx_E4BN0tLDUtC6KkGSl9yU4/'
url = URL + f'sendaudio?chat_id=516449722'
files = {'audio': buf.getvalue()}
r = requests.post(url, files=files)

# %%
file=audio.export(format="wav")

# %%
import io
buf = io.BytesIO()
audio.export(buf, format="wav")
buf.getvalue()
# Out:
# b'RIFF$\xbb\x03\x00WAVEfmt \x10\x00\x00\x00\x01\x00\x01\x00\x80>\x00\x00\x00\xfa\x00\x00\x04\x00 \x00data\
# ...

# %%
 bytes.fromhex(file)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-153-9e687dd141ba> in <module>
# ----> 1 bytes.fromhex(file)
#
# TypeError: fromhex() argument must be str, not _io.BufferedRandom

# %%
result
# Out:
# <_io.BufferedRandom name='mashup.wav'>

# %%
r=requests.get(url_audio)

# %%
import io
from pydub import AudioSegment
#current_data is defined as the stream of bytes that you receive
s = io.BytesIO(r.content)
seg = AudioSegment.from_raw(r.content, sample_width=2, frame_rate=32000, channels=2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-102-ab6442cba739> in <module>
#       3 #current_data is defined as the stream of bytes that you receive
#       4 s = io.BytesIO(r.content)
# ----> 5 seg = AudioSegment.from_raw(r.content, sample_width=2, frame_rate=32000, channels=2)
#
# ~/.local/lib/python3.8/site-packages/pydub/audio_segment.py in from_raw(cls, file, **kwargs)
#     752     @classmethod
#     753     def from_raw(cls, file, **kwargs):
# --> 754         return cls.from_file(file, 'raw', sample_width=kwargs['sample_width'], frame_rate=kwargs['frame_rate'],
#     755                              channels=kwargs['channels'])
#     756
#
# ~/.local/lib/python3.8/site-packages/pydub/audio_segment.py in from_file(cls, file, format, codec, parameters, **kwargs)
#     651                 'frame_width': channels * sample_width
#     652             }
# ...

# %%
r.content
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00`\x00`\x00\x00\xff\xdb\x00C\x00\x04\x03\x03\x04\x03\x03\x04\x04\x03\x04\x05\x04\x04\x05\x06\n\x07\x06\x06\x06\x06\r\t\n\x08\n\x0f\r\x10\x10\x0f\r\x0f\x0e\x11\x13\x18\x14\x11\x12\x17\x12\x0e\x0f\x15\x1c\x15\x17\x19\x19\x1b\x1b\x1b\x10\x14\x1d\x1f\x1d\x1a\x1f\x18\x1a\x1b\x1a\xff\xdb\x00C \x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1c\x00\x00\x02\x02\x03\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x04\x05\x03\x06\x01\x02\x07\x00\x08\xff\xc4\x00E\x10\x00\x02\x01\x03\x03\x02\x05\x01\x05\x06\x05\x03\x03\x04\x00\x07\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13"Qaq\x142\x81\x91\xa1\x07#B\xb1\xc1\xd1\x15Rb\xe1\xf03r\xf1\x16$\x82CS\x92\xa2%4\xb25s\x
# ...

# %%
img = cv2.imdecode(np.frombuffer(r.content, dtype=np.uint8), cv2.IMREAD_UNCHANGED)
im_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
cv2.imshow('img',im_rgb)

# %%
r.ok
# Out:
# True

# %%
len(r.content)
# Out:
# 76776

# %%
file = open("sample_image.jpg", "wb")
file.write(r.content)
file.close()

# %%
import psycopg2

# %%
update_id=2
column='update_id'

# %%
f""" select 1 from  update_info where {column}= {update_id} """
# Out:
# ' select 1 from  update_info where update_id= 2 '

# %%
t_host = "localhost"
t_port = "5432" #5432 is typically default port
t_dbname = "postgres"
t_name_user = "postgres"
t_password = "1"
data_conn = psycopg2.connect(host=t_host, port=t_port, dbname=t_dbname, user=t_name_user, password=t_password)

# %%
cur = data_conn.cursor()
cur.execute("SELECT datname FROM pg_catalog.pg_database")
exists = cur.fetchall()
cur.close()
data_conn.close()

# %%
telegram_bot_db

# %%
exists
# Out:
# [('postgres',), ('template1',), ('template0',), ('test',), ('telebot_db',)]

# %%
cur.close()
data_conn.close()

# %%
data_conn.close()

# %%
if not exists:
    cursor.execute('CREATE DATABASE python_db')

# %%
data_conn.close()

# %%
import psycopg2
from psycopg2 import sql
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT # <-- ADD THIS LINE

con = psycopg2.connect(host=t_host, port=t_port, dbname=t_dbname, user=t_name_user, password=t_password)

con.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT) # <-- ADD THIS LINE

cur = con.cursor()

# Use the psycopg2.sql module instead of string concatenation 
# in order to avoid sql injection attacs.
cur.execute(sql.SQL("CREATE DATABASE {}").format(
        sql.Identifier('test'))
    )
# Out:
# ---------------------------------------------------------------------------
# DuplicateDatabase                         Traceback (most recent call last)
# <ipython-input-16-f9edd214cb7b> in <module>
#      11 # Use the psycopg2.sql module instead of string concatenation
#      12 # in order to avoid sql injection attacs.
# ---> 13 cur.execute(sql.SQL("CREATE DATABASE {}").format(
#      14         sql.Identifier('test'))
#      15     )
#
# DuplicateDatabase: database "test" already exists

# %%
cur.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-d4424d4927ea> in <module>
#       1 cur.close()
# ----> 2 conn.close()
#
# NameError: name 'conn' is not defined

# %%
import psycopg2
try:
    connection = psycopg2.connect(user = "postgres",
                                  password = "1",
                                  host = "localhost",
                                  port = "5432",
                                  database = "test")

    cursor = connection.cursor()
    # Print PostgreSQL Connection properties
    print ( connection.get_dsn_parameters(),"\n")

    # Print PostgreSQL version
    cursor.execute("SELECT version();")
    record = cursor.fetchone()
    print("You are connected to - ", record,"\n")

except (Exception, psycopg2.Error) as error :
    print ("Error while connecting to PostgreSQL", error)
finally:
    #closing database connection.
        if(connection):
            cursor.close()
            connection.close()
            print("PostgreSQL connection is closed")
# Out:
# {'user': 'postgres', 'dbname': 'test', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'gssencmode': 'prefer', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 12.2 (Ubuntu 12.2-4) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 9.3.0-8ubuntu1) 9.3.0, 64-bit',)
#
# PostgreSQL connection is closed

# %%
import psycopg2
from psycopg2 import Error

try:
    connection = psycopg2.connect(user = "postgres",
                                  password = "1",
                                  host = "localhost",
                                  port = "5432",
                                  database = "test")

    cursor = connection.cursor()
    
    create_table_query = '''CREATE TABLE images
          (ID INT PRIMARY KEY     NOT NULL,
          image           bytea    NOT NULL
          ); '''
    
    cursor.execute(create_table_query)
    connection.commit()
    print("Table created successfully in PostgreSQL ")

except (Exception, psycopg2.DatabaseError) as error :
    print ("Error while creating PostgreSQL table", error)
finally:
    #closing database connection.
        if(connection):
            cursor.close()
            connection.close()
            print("PostgreSQL connection is closed")
# Out:
# Table created successfully in PostgreSQL
# PostgreSQL connection is closed

# %%
    postgres_insert_query = """ INSERT INTO images (ID, image) VALUES (%s,%s)"""
    record_to_insert = (8, r.content)
    cursor.execute(postgres_insert_query, record_to_insert)

# %%
import psycopg2

try:
    connection = psycopg2.connect(user = "postgres",
                                  password = "1",
                                  host = "localhost",
                                  port = "5432",
                                  database = "test")
    cursor = connection.cursor()

    postgres_insert_query = """ INSERT INTO images (ID, image) VALUES (%s,%s)"""
    record_to_insert = (157, 'добрый день')
    cursor.execute(postgres_insert_query, record_to_insert)

    connection.commit()
    count = cursor.rowcount
    print (count, "Record inserted successfully into mobile table")

except (Exception, psycopg2.Error) as error :
    if(connection):
        print("Failed to insert record into mobile table", error)

finally:
    #closing database connection.
    if(connection):
        cursor.close()
        connection.close()
        print("PostgreSQL connection is closed")
# Out:
# Failed to insert record into mobile table duplicate key value violates unique constraint "images_pkey"
# DETAIL:  Key (id)=(157) already exists.
#
# PostgreSQL connection is closed

# %%
r.content
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00`\x00`\x00\x00\xff\xdb\x00C\x00\x04\x03\x03\x04\x03\x03\x04\x04\x03\x04\x05\x04\x04\x05\x06\n\x07\x06\x06\x06\x06\r\t\n\x08\n\x0f\r\x10\x10\x0f\r\x0f\x0e\x11\x13\x18\x14\x11\x12\x17\x12\x0e\x0f\x15\x1c\x15\x17\x19\x19\x1b\x1b\x1b\x10\x14\x1d\x1f\x1d\x1a\x1f\x18\x1a\x1b\x1a\xff\xdb\x00C \x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1c\x00\x00\x02\x02\x03\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x04\x05\x03\x06\x01\x02\x07\x00\x08\xff\xc4\x00E\x10\x00\x02\x01\x03\x03\x02\x05\x01\x05\x06\x05\x03\x03\x04\x00\x07\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13"Qaq\x142\x81\x91\xa1\x07#B\xb1\xc1\xd1\x15Rb\xe1\xf03r\xf1\x16$\x82CS\x92\xa2%4\xb25s\x
# ...

# %%
encode(content_file::bytea, 'hex')

# %%
import psycopg2

try:
    connection = psycopg2.connect(user = "postgres",
                              password = "1",
                              host = "localhost",
                              port = "5432",
                              database = "telebot_db")
    cursor = connection.cursor()
    postgreSQL_select_Query = "select * from chat_info"

    cursor.execute(postgreSQL_select_Query)
    print("Selecting rows from mobile table using cursor.fetchall")
    mobile_records = cursor.fetchall() 

    print("Print each row and it's columns values")
    for row in mobile_records:
        a=row[1]
       
except (Exception, psycopg2.Error) as error :
    print ("Error while fetching data from PostgreSQL", error)

finally:
    #closing database connection.
    if(connection):
        cursor.close()
        connection.close()
        print("PostgreSQL connection is closed")
# Out:
# Selecting rows from mobile table using cursor.fetchall
# Print each row and it's columns values
# PostgreSQL connection is closed

# %%
mobile_records
# Out:
# [(516449722, 'Иван', 'Надин', False)]

# %%
value
# Out:
# "'telebot_db'"

# %%
a=1
b=2
c=3
for i in [a,b,c]:
    print(i)
# Out:
# 1
# 2
# 3

# %%
f""" sadas {value} """
# Out:
# " sadas 'telebot_db' "

# %%
result = bytes.fromhex(mobile_records[-1][0])
result.decode("utf-8")
# Out:
# 'приветтт'

# %%
result.decode("utf-8")
# Out:
# 'sadasdada'

# %%
mobile_records
# Out:
# [(<memory at 0x7efcc8a81f40>,)]

# %%
for row in mobile_records:
        a=row[0]
        print(a)
# Out:
# 372935336
# 372935341
# 372935339
# 372935340
# 372935337
# 372935338
# 372935334
# 372935335

# %%
a=row[6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-86-d546e575f55e> in <module>
# ----> 1 a=row[6]
#
# IndexError: tuple index out of range

# %%
result = bytes.fromhex(a)
img = cv2.imdecode(np.fromstring(result, dtype=np.uint8), cv2.IMREAD_UNCHANGED)
im_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
imgplot = plt.imshow(im_rgb)
plt.show()
# Out:
# <ipython-input-83-9c26f2ce97d1>:2: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   img = cv2.imdecode(np.fromstring(result, dtype=np.uint8), cv2.IMREAD_UNCHANGED)

# %%
result = bytes.fromhex(a)

# %%
class Test(object):
    def _decorator(foo):
        def magic( self ) :
            print("start magic")
            foo( self )
            print("end magic")
        return magic

    @_decorator
    def bar( self ) :
        print("normal call")

test = Test()

test.bar()
# Out:
# start magic
# normal call
# end magic

# %%
'pg_catalog.pg_database','datname'

# %%
a.connection
# Out:
# <connection object at 0x7fa035751040; dsn: 'user=postgres password=xxx dbname=postgres host=localhost port=5432', closed: 0>

# %%
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT
a.connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

# %%
'select datname from pg_catalog.pg_database'

# %%
a=Postgres()
# Out:
# connecting to PostgreSQL database...
# connection established
# PostgreSQL 12.2 (Ubuntu 12.2-4) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 9.3.0-8ubuntu1) 9.3.0, 64-bit

# %%
result=a.query('select * from pg_catalog.pg_database')

# %%
result

# %%
db_config = {'dbname': 'postgres', 'host': 'localhost',
                     'password': '1', 'port': 5432, 'user': 'postgres'}
conn=psycopg2.connect(**db_config)

# %%
cursor=conn.cursor()

# %%
cursor.execute('select * from pg_catalog.pg_database')

# %%
cursor.fetchone()
# Out:
# (13465,
#  'postgres',
#  10,
#  6,
#  'ru_RU.UTF-8',
#  'ru_RU.UTF-8',
#  False,
#  True,
#  -1,
#  13464,
#  '479',
#  '1',
#  1663,
#  None)

# %%
class Connector(Database):

# %%
def decorator_function(func):
    def wrapper():
        print('Функция-обёртка!')
        print('Оборачиваемая функция: {}'.format(func))
        print('Выполняем обёрнутую функцию...')
        func()
        print('Выходим из обёртки')
    return wrapper

# %%
@decorator_function
def hello_world():
    print('Hello world!')

# %%
def benchmark(func):
    import time
    
    def wrapper():
        start = time.time()
        func()
        end = time.time()
        print('[*] Время выполнения: {} секунд.'.format(end-start))
    return wrapper

@benchmark
def fetch_webpage():
    import requests
    webpage = requests.get('https://google.com')

fetch_webpage()
# Out:
# [*] Время выполнения: 1.035787582397461 секунд.

# %%
def decorator_cursor(function_query)

# %%
def a_decorator_passing_arguments(function_to_decorate):
    def a_wrapper_accepting_arguments(arg1, arg2): # аргументы прибывают отсюда
        a=5
        print("Смотри, что я получил:", arg1, arg2)
        result=function_to_decorate(a,arg1, arg2)
        
    return a_wrapper_accepting_arguments
   
 
# Теперь, когда мы вызываем функцию, которую возвращает декоратор,
# мы вызываем её "обёртку", передаём ей аргументы и уже в свою очередь
# она передаёт их декорируемой функции
 
@a_decorator_passing_arguments
def print_full_name(a,first_name, last_name):
    print ("Меня зовут", first_name, last_name)
    b=a+5
    return b
 
result,result1=print_full_name("Питер", "Венкман")
# Out:
# Смотри, что я получил: Питер Венкман
# Меня зовут Питер Венкман
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-bf488e5fc9f6> in <module>
#      18     return b
#      19
# ---> 20 result,result1=print_full_name("Питер", "Венкман")
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
print(result1)
# Out:
# 10

# %%
class Table:
    def __init__(self, l, w, h):
        self.lenght = l
        self.width = w
        self.height = h
 
class KitchenTable(Table):
    def setPlaces(self, p):
        self.places = p
 
class DeskTable(Table):
    def square(self):
        return self.width * self.length

# %%
t1 = KitchenTable()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-fb2de5845863> in <module>
# ----> 1 t1 = KitchenTable()
#
# TypeError: __init__() missing 3 required positional arguments: 'l', 'w', and 'h'

# %%
t1 = KitchenTable(2, 2, 0.7)

# %%
connect.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

# %%
connect = psycopg2.connect(user = "postgres",
                              password = "1",
                              host = "localhost",
                              port = "5432",
                              database = "telebot_db")

# %%
 def insert_into_update_files(con*args): 
        
    postgres_insert_query = """ INSERT INTO update_files (update_id, file_id,content_file,type_file)
                                    VALUES (%s,%s,%s,%s)"""
    
    record_to_insert = tuple([val for val in args])
    print(postgres_insert_query%record_to_insert)
insert_into_update_files(1,2,3,4)
# Out:
#  INSERT INTO update_files (update_id, file_id,content_file,type_file)
#                                    VALUES (1,2,3,4)

# %%
table='pg_catalog.pg_database'

# %%
column
# Out:
# 'datname'

# %%
record=(table,column)
query="""select * from %s where %s='telebot_db'"""
print(query%record)
# Out:
# select * from pg_catalog.pg_database where datname='telebot_db'

# %%
'datname',"'"+'telebot_db'+"'"

# %%
@cursor
def execute_cursor(curs,connect,*args):
    
    query="""select * from %s where %s='telebot_db'"""
    print(args[0])
    curs.execute(query%args)
    print(curs.fetchone())

# %%
execute_cursor(connect,table,column)
# Out:
# pg_catalog.pg_database
# (16641, 'telebot_db', 10, 6, 'ru_RU.UTF-8', 'ru_RU.UTF-8', False, True, -1, 13464, '479', '1', 1663, None)

# %%
connect.close()

# %%
conn.close()

# %%
def cursor(f):
    def cursor(connect,*args):
        curs=connect.cursor()
        args=tuple([item for item in args])
        try:
            f(curs,connect,*args)
        except (Exception, psycopg2.Error) as error :
            print ("Error while connecting to PostgreSQL", error)
        finally:
            curs.close()
    return cursor

# %%
C
    postgres_insert_query = """ INSERT INTO update_files (update_id, file_id,content_file,type_file)
                                    VALUES (%s,%s,%s,%s)"""
    record_to_insert = (**args)
    return query
# Out:
#   File "<ipython-input-68-2ae67f3aee47>", line 4
#     record_to_insert = (**args)
#                         ^
# SyntaxError: invalid syntax

# %%
@with_connection
def do_some_job(cnn, arg1=None, arg2=None):
    cur = cnn.cursor()
    cur.execute(sql) # or something else
    print(arg1)
    return cur.fetchone()

a=do_some_job(arg1=5)
# Out:
# 13

# %%
a

# %%
sql='select * from pg_catalog.pg_database'

# %%
def with_connection(f):
    def with_connection_(arg1):
        # or use a pool, or a factory function...
        cnn = psycopg2.connect(user = "postgres",
                              password = "1",
                              host = "localhost",
                              port = "5432",
                              database = "telebot_db")
        arg1=arg1+8
        try:
            rv = f(cnn,arg1)
        except :
            cnn.rollback()
            raise
        else:
            cnn.commit() # or maybe not
        finally:
            cnn.close()

        

    return with_connection_
